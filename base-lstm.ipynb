# %%
import pandas as pd
import numpy as np
# Out:
# c:\Users\AKSHAT SHAW\anaconda3\Lib\site-packages\pandas\core\arrays\masked.py:60: UserWarning: Pandas requires version '1.3.6' or newer of 'bottleneck' (version '1.3.5' currently installed).
#   from pandas.core import (

# %%
df_3005 = pd.read_csv(r"C:/Users/AKSHAT SHAW/OneDrive - iitr.ac.in/Desktop/Spark_25_project/03005.csv")

# %%
df_3005.head()
# Out:
#    prcp(mm/day)  tmax(C)  tmin(C)  tavg(C)  srad_lw(w/m2)  srad_sw(w/m2)  \
# 0          0.00    28.00    13.21    20.60         340.89         250.87
# 1          0.07    28.06    14.49    21.28         357.40         238.01
# 2          0.45    27.19    13.63    20.41         362.47         202.55
# 3          0.72    26.27    13.38    19.82         366.46         173.07
# 4          3.11    23.99    14.17    19.08         377.85         119.04
#
#    wind_u(m/s)  wind_v(m/s)  wind(m/s)  rel_hum(%)  ...  sm_lvl4(kg/m2)  \
# 0         1.58         1.51       2.19       48.39  ...          531.81
# 1         0.85         0.34       0.92       55.88  ...          531.75
# 2        -0.35        -1.36       1.40       57.16  ...          531.70
# 3        -2.01        -0.60       2.10       80.77  ...          531.66
# 4        -1.01        -1.73       2.00       84.53  ...          531.63
#
#    Soil_Moisture_Sum  Soil_Saturation  soil_awsc_max  Actual_Soil_Saturation  \
# 0             786.30           784.76            150                5.231733
# 1             785.85           784.65            150                5.231000
# 2             785.48           784.92            150                5.232800
# 3             785.66           784.98            150                5.233200
# 4             787.46           789.50            150                5.263333
#
#          date       AWC  Actual_Soil_Saturation_New  station_id  soil_awc_avg
# 0  01-01-1980  0.196154                 4000.731109        3005      0.196154
# 1  02-01-1980  0.196154                 4000.170325        3005      0.196154
# 2  03-01-1980  0.196154                 4001.546794        3005      0.196154
# 3  04-01-1980  0.196154                 4001.852676        3005      0.196154
# 4  05-01-1980  0.196154                 4024.895777        3005      0.196154
#
# [5 rows x 28 columns]

# %%
df_base = pd.read_csv(r"C:/Users/AKSHAT SHAW/OneDrive - iitr.ac.in/Desktop/Spark_25_project/baseflow_all_basins.csv")

# %%
df_base.head()
# Out:
#          date  3002       3005       3008  3013       3018  3019   3020  3029  \
# 0  1980-01-01   NaN  23.200000  36.100000   NaN  30.700000   NaN  12.80  15.1
# 1  1980-01-02   NaN  22.000000  35.781102   NaN  31.012728   NaN  12.30  15.3
# 2  1980-01-03   NaN  21.400000  35.465957   NaN  30.000000   NaN  11.10  14.6
# 3  1980-01-04   NaN  21.384851  35.155992   NaN  29.800000   NaN   9.70  14.3
# 4  1980-01-05   NaN  21.369522  34.850262   NaN  29.200000   NaN   8.67  14.0
#
#    3030  ...  15024      15026     15030  15032  17003     17006       17011  \
# 0   NaN  ...    NaN  50.900000  4.800000  116.0    2.2  3.800000  462.200000
# 1   NaN  ...    NaN  49.049024  4.500000  112.8    2.1  3.500000  458.210089
# 2   NaN  ...    NaN  47.262349  4.477016  112.6    2.1  3.100000  454.313717
# 3   NaN  ...    NaN  45.562745  4.400000  106.5    2.0  3.096050  445.800000
# 4   NaN  ...    NaN  43.923668  4.200000  106.3    2.0  3.092284  439.600000
#
#        17019      17022  10013
# 0  23.700000  10.300000    NaN
# 1  24.000000   8.638803    NaN
# 2  25.965158   5.800000    NaN
# 3  28.128636   4.737067    NaN
# 4  30.505124   3.938515    NaN
#
# [5 rows x 139 columns]

# %% [markdown]
# ## Taking on the baseflow values from here:

# %%
df_base = df_base[['date', '3005']]

# %%
df_base.head()
# Out:
#          date       3005
# 0  1980-01-01  23.200000
# 1  1980-01-02  22.000000
# 2  1980-01-03  21.400000
# 3  1980-01-04  21.384851
# 4  1980-01-05  21.369522

# %%
df_3005['date'] = pd.to_datetime(df_3005['date'], format='mixed', dayfirst=True, errors='coerce')
df_base['date'] = pd.to_datetime(df_base['date'], format='mixed', dayfirst=True, errors='coerce')

# %%
# Merge two DataFrames on a single column
merged_df = pd.merge(df_3005, df_base, on='date', how='inner')

# %%
merged_df.head()
# Out:
#    prcp(mm/day)  tmax(C)  tmin(C)  tavg(C)  srad_lw(w/m2)  srad_sw(w/m2)  \
# 0          0.00    28.00    13.21    20.60         340.89         250.87
# 1          0.07    28.06    14.49    21.28         357.40         238.01
# 2          0.45    27.19    13.63    20.41         362.47         202.55
# 3          0.72    26.27    13.38    19.82         366.46         173.07
# 4          3.11    23.99    14.17    19.08         377.85         119.04
#
#    wind_u(m/s)  wind_v(m/s)  wind(m/s)  rel_hum(%)  ...  Soil_Moisture_Sum  \
# 0         1.58         1.51       2.19       48.39  ...             786.30
# 1         0.85         0.34       0.92       55.88  ...             785.85
# 2        -0.35        -1.36       1.40       57.16  ...             785.48
# 3        -2.01        -0.60       2.10       80.77  ...             785.66
# 4        -1.01        -1.73       2.00       84.53  ...             787.46
#
#    Soil_Saturation  soil_awsc_max  Actual_Soil_Saturation       date  \
# 0           784.76            150                5.231733 1980-01-01
# 1           784.65            150                5.231000 1980-01-02
# 2           784.92            150                5.232800 1980-01-03
# 3           784.98            150                5.233200 1980-01-04
# 4           789.50            150                5.263333 1980-01-05
#
#         AWC  Actual_Soil_Saturation_New  station_id  soil_awc_avg       3005
# 0  0.196154                 4000.731109        3005      0.196154  23.200000
# 1  0.196154                 4000.170325        3005      0.196154  22.000000
# 2  0.196154                 4001.546794        3005      0.196154  21.400000
# 3  0.196154                 4001.852676        3005      0.196154  21.384851
# 4  0.196154                 4024.895777        3005      0.196154  21.369522
#
# [5 rows x 29 columns]

# %%
len(df_3005), len(df_base), len(merged_df)
# Out:
# (14976, 14555, 14555)

# %% [markdown]
# ## Loading the static variables

# %%
merged_df.columns
# Out:
# Index(['prcp(mm/day)', 'tmax(C)', 'tmin(C)', 'tavg(C)', 'srad_lw(w/m2)',
#        'srad_sw(w/m2)', 'wind_u(m/s)', 'wind_v(m/s)', 'wind(m/s)',
#        'rel_hum(%)', 'pet(mm/day)', 'pet_gleam(mm/day)', 'aet_gleam(mm/day)',
#        'evap_canopy(kg/m2/s)', 'evap_surface(kg/m2/s)', 'sm_lvl1(kg/m2)',
#        'sm_lvl2(kg/m2)', 'sm_lvl3(kg/m2)', 'sm_lvl4(kg/m2)',
#        'Soil_Moisture_Sum', 'Soil_Saturation', 'soil_awsc_max',
#        'Actual_Soil_Saturation', 'date', 'AWC', 'Actual_Soil_Saturation_New',
#        'station_id', 'soil_awc_avg', '3005'],
#       dtype='object')

# %%
merged_df.dropna(inplace=True)
merged_df.drop(columns=['date', 'station_id'], inplace = True)

# %%
# merged_df.to_csv("merged_df_3005.csv", index=False)

# %%
import pandas as pd
merged_df = pd.read_csv("merged_df_3005.csv")
# Out:
# c:\Users\AKSHAT SHAW\anaconda3\Lib\site-packages\pandas\core\arrays\masked.py:60: UserWarning: Pandas requires version '1.3.6' or newer of 'bottleneck' (version '1.3.5' currently installed).
#   from pandas.core import (

# %%
df_static = pd.read_csv("static_3005.csv").drop("gauge_id", axis=1)

# %%
# merged_df.select_dtypes(include=['object']).columns
cat = merged_df.select_dtypes(include=['object', 'string']).columns
cat
# Out:
# Index(['high_prec_timing', 'low_prec_timing', 'geol_class_1st',
#        'geol_class_2nd', 'dom_land_cover', 'ghi_stn_id', 'cwc_site_name',
#        'river_basin', 'cwc_river', 'ghi_group', 'hsg_major'],
#       dtype='object')

# %%
row = df_static.loc[0]
n = len(merged_df)
duplicates = pd.DataFrame([row] * n, index=merged_df.index)

# %%
merged_df = pd.concat([merged_df, duplicates], axis=1)
merged_df
# Out:
#        prcp(mm/day)  tmax(C)  tmin(C)  tavg(C)  srad_lw(w/m2)  srad_sw(w/m2)  \
# 0              0.00    25.04    11.41    18.23         314.58         258.67
# 1              0.00    26.31    10.82    18.56         314.52         258.90
# 2              0.00    26.91    11.11    19.01         331.02         254.07
# 3              0.04    27.39    12.08    19.74         327.08         255.51
# 4              0.00    27.61    12.80    20.20         335.49         253.44
# ...             ...      ...      ...      ...            ...            ...
# 13880          3.31    31.82    18.37    25.10         388.79         216.89
# 13881          0.30    32.46    17.71    25.08         379.81         299.56
# 13882          0.00    31.39    17.18    24.28         343.19         325.07
# 13883          0.00    30.02    14.74    22.38         339.18         332.44
# 13884          0.00    31.06    13.21    22.14         338.91         335.81
#
#        wind_u(m/s)  wind_v(m/s)  wind(m/s)  rel_hum(%)  ...  \
# 0             0.35        -1.01       1.07       66.79  ...
# 1            -0.14         0.48       0.50       66.48  ...
# 2             1.07         0.67       1.26       60.66  ...
# 3             1.28         0.42       1.35       56.66  ...
# 4             1.99        -0.40       2.03       58.37  ...
# ...            ...          ...        ...         ...  ...
# 13880        -0.61         1.98       2.32       69.39  ...
# 13881         1.96         0.01       2.42       47.56  ...
# 13882         2.47        -1.93       3.18       34.43  ...
# 13883         0.55        -2.03       2.19       36.26  ...
# 13884        -0.52        -0.63       1.33       33.22  ...
#
#        bulkdens_sub_major  bulkdens_sub_mean  org_carb_top_major  \
# 0                    1.21           1.218816                0.75
# 1                    1.21           1.218816                0.75
# 2                    1.21           1.218816                0.75
# 3                    1.21           1.218816                0.75
# 4                    1.21           1.218816                0.75
# ...                   ...                ...                 ...
# 13880                1.21           1.218816                0.75
# 13881                1.21           1.218816                0.75
# 13882                1.21           1.218816                0.75
# 13883                1.21           1.218816                0.75
# 13884                1.21           1.218816                0.75
#
#        org_carb_top_mean  org_carb_sub_major  org_carb_sub_mean  \
# 0               0.956513                0.45            0.32039
# 1               0.956513                0.45            0.32039
# 2               0.956513                0.45            0.32039
# 3               0.956513                0.45            0.32039
# 4               0.956513                0.45            0.32039
# ...                  ...                 ...                ...
# 13880           0.956513                0.45            0.32039
# 13881           0.956513                0.45            0.32039
# 13882           0.956513                0.45            0.32039
# 13883           0.956513                0.45            0.32039
# 13884           0.956513                0.45            0.32039
#
#        organic_frac_top  organic_frac_sub  hsg_major       wtd
# 0              0.020042          0.007882          D -0.098991
# 1              0.020042          0.007882          D -0.098991
# 2              0.020042          0.007882          D -0.098991
# 3              0.020042          0.007882          D -0.098991
# 4              0.020042          0.007882          D -0.098991
# ...                 ...               ...        ...       ...
# 13880          0.020042          0.007882          D -0.098991
# 13881          0.020042          0.007882          D -0.098991
# 13882          0.020042          0.007882          D -0.098991
# 13883          0.020042          0.007882          D -0.098991
# 13884          0.020042          0.007882          D -0.098991
#
# [13885 rows x 415 columns]

# %%
from sklearn.preprocessing import LabelEncoder, OrdinalEncoder

# Assuming 'categorical_columns' is a list of the names of the categorical columns
categorical_columns =cat # replace with your categorical column names

label_encoders = {}
for column in categorical_columns:
    le = OrdinalEncoder()
    merged_df[column] = le.fit_transform(merged_df[column])
    label_encoders[column] = le

# %%
import torch 
import torch.nn as nn
import torch.optim as optim
import torch.nn.functional as F

from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import LabelEncoder

# %%
s = len(merged_df)

# %%
from torch.utils.data import Dataset, DataLoader, TensorDataset

X = merged_df.drop('3005', axis=1) 
y = merged_df['3005']

X_train = X[:round(s*0.8)]
y_train = y[:round(s*0.8)]

X_test = X[round(s*0.9):]
y_test = y[round(s*0.9):]

X_val = X[round(s*0.8):round(s*0.9)]
y_val = y[round(s*0.8):round(s*0.9)]


scaler = StandardScaler()
X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)
X_val = scaler.transform(X_val)

# %%
X_test.shape, y_test.shape
# Out:
# ((1389, 414), (1389,))

# %%
# X_train_tensor = torch.from_numpy(X_train.astype(np.float32))
# X_test_tensor = torch.from_numpy(X_test.astype(np.float32))
# y_train_tensor = torch.from_numpy(y_train.to_numpy().astype(np.float32))
# y_test_tensor = torch.from_numpy(y_test.to_numpy().astype(np.float32))

# %%
class CustomDataset(Dataset):
  def __init__(self, features, labels):
    self.features = features
    self.labels = labels

  def __len__(self):
    return len(self.features)

  def __getitem__(self, idx):
    return self.features[idx], self.labels[idx]
  
class SequenceDataset(Dataset):
    def __init__(self, features, labels, sequence_length = 20):
        """
        features: shape (N, num_features)
        labels: shape (N,) or (N, 1)
        sequence_length: number of time steps in each input sequence
        """
        self.sequence_length = sequence_length

        self.features = torch.tensor(features, dtype=torch.float32)
        self.labels = torch.tensor(labels.to_numpy(), dtype=torch.float32)

        # Ensure labels have shape (N, 1)
        if self.labels.ndim == 1:
            self.labels = self.labels.unsqueeze(1)

    def __len__(self):
        return len(self.features) - self.sequence_length

    def __getitem__(self, idx):
        x = self.features[idx : idx + self.sequence_length]  # shape: (seq_len, num_features)
        y = self.labels[idx + self.sequence_length]          # target: next step
        return x, y

# %%
train_dataset = SequenceDataset(X_train, y_train)
test_dataset = SequenceDataset(X_test, y_test)
val_dataset = SequenceDataset(X_val, y_val)

train_loader = DataLoader(
                    train_dataset,
                    batch_size=32,
                    shuffle=True)

test_loader = DataLoader(
                    test_dataset,
                    batch_size=32,
                    shuffle=True)
val_loader = DataLoader(
                    val_dataset,
                    batch_size=32,
                    shuffle=True
)

# %%
class LSTMModel(nn.Module):
    def __init__(self, input_size, hidden_size, num_layers):
        super().__init__()
        
        self.lstm = nn.LSTM(input_size, hidden_size, num_layers, batch_first=True)
        self.lstm2 = nn.LSTM(hidden_size, hidden_size, num_layers, batch_first=True)
        self.fc = nn.Linear(hidden_size, 1)

        # # Map static features to initial hidden and cell state
        # self.static_to_h = nn.Linear(static_size, hidden_size * num_layers)
        # self.static_to_c = nn.Linear(static_size, hidden_size * num_layers)

        # # Map static -> (batch_size, hidden_size * num_layers)
        # h0 = self.static_to_h(x_static).view(self.num_layers, batch_size, self.hidden_size)
        # c0 = self.static_to_c(x_static).view(self.num_layers, batch_size, self.hidden_size)

    def forward(self, x):
        # batch_size = x.size(0)
        out, _ = self.lstm(x)  # out: (batch, seq_len, hidden)
        out, _ = self.lstm2(out)
        out = out[:, -1, :]    # take last time step
        return self.fc(out)

# %%
num_features = X_train.shape[1]
model = LSTMModel(input_size=num_features, hidden_size=64, num_layers=1)
model.to("cuda")
# Out:
# LSTMModel(
#   (lstm): LSTM(414, 64, batch_first=True)
#   (lstm2): LSTM(64, 64, batch_first=True)
#   (fc): Linear(in_features=64, out_features=1, bias=True)
# )

# %%
import wandb
wandb.login()
# Out:
# True

# %%
wandb.init(project="spark'25-lstm-testing", config={
    "epochs": 100,
    "batch_size": 64,
    "lr": 0.0001,
    "optimizer": "Adam",
    "loss_fn": "MSELoss",
    "model": "LSTM"
})
# Out:
# Tracking run with wandb version 0.19.1
# Run data is saved locally in <code>c:\Users\AKSHAT SHAW\OneDrive - iitr.ac.in\Desktop\Spark_25_project\wandb\run-20250521_210159-dw501k11</code>
# Syncing run <strong><a href='https://wandb.ai/akshatshaw47-iit-roorkee/spark%2725-lstm-testing/runs/dw501k11' target="_blank">efficient-wood-1</a></strong> to <a href='https://wandb.ai/akshatshaw47-iit-roorkee/spark%2725-lstm-testing' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>
#  View project at <a href='https://wandb.ai/akshatshaw47-iit-roorkee/spark%2725-lstm-testing' target="_blank">https://wandb.ai/akshatshaw47-iit-roorkee/spark%2725-lstm-testing</a>
#  View run at <a href='https://wandb.ai/akshatshaw47-iit-roorkee/spark%2725-lstm-testing/runs/dw501k11' target="_blank">https://wandb.ai/akshatshaw47-iit-roorkee/spark%2725-lstm-testing/runs/dw501k11</a>
# <button onClick="this.nextSibling.style.display='block';this.style.display='none';">Display W&B run</button><iframe src='https://wandb.ai/akshatshaw47-iit-roorkee/spark%2725-lstm-testing/runs/dw501k11?jupyter=true' style='border:none;width:100%;height:420px;display:none;'></iframe>

# %%
criterion = nn.MSELoss()
optimizer = optim.Adam(model.parameters(), lr=0.0001)
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
# Training loop with validation
for epoch in range(1000):
    model.train()
    train_loss = 0.0
    for xb, yb in train_loader:
        xb, yb = xb.to(device), yb.to(device)
        pred = model(xb)
        loss = criterion(pred, yb)

        optimizer.zero_grad()
        loss.backward()
        optimizer.step()

        train_loss += loss.item()

    # Validation
    model.eval()
    val_loss = 0.0
    with torch.no_grad():
        for xb, yb in val_loader:
            xb, yb = xb.to(device), yb.to(device)
            pred = model(xb)
            loss = criterion(pred, yb)
            val_loss += loss.item()

    train_loss /= len(train_loader)
    val_loss /= len(val_loader)

    print(f"Epoch {epoch+1}, Train Loss: {train_loss:.4f}, Val Loss: {val_loss:.4f}")
# Epoch 187, Train Loss: 1.1319, Val Loss: 285.1645
# Epoch 188, Train Loss: 0.8467, Val Loss: 276.9410
# Epoch 189, Train Loss: 1.2090, Val Loss: 282.2344
# Epoch 190, Train Loss: 0.9076, Val Loss: 320.5781
# Epoch 191, Train Loss: 0.9635, Val Loss: 296.9877
# Epoch 192, Train Loss: 0.7702, Val Loss: 271.6466
# Epoch 193, Train Loss: 1.4595, Val Loss: 294.0869
# Epoch 194, Train Loss: 0.9069, Val Loss: 287.7851
# Epoch 195, Train Loss: 0.7441, Val Loss: 308.0027
# Epoch 196, Train Loss: 0.6405, Val Loss: 305.1929
# Epoch 197, Train Loss: 0.8528, Val Loss: 301.3076
# Epoch 198, Train Loss: 0.7802, Val Loss: 300.7447
# Epoch 199, Train Loss: 1.0437, Val Loss: 308.3989
# Epoch 200, Train Loss: 0.9926, Val Loss: 291.9153
# Epoch 201, Train Loss: 0.7354, Val Loss: 302.9804
# Epoch 202, Train Loss: 0.7229, Val Loss: 283.5934
# Epoch 203, Train Loss: 0.8426, Val Loss: 287.9705
# Epoch 204, Train Loss: 1.1908, Val Loss: 288.2962
# Epoch 205, Train Loss: 1.0558, Val Loss: 294.2161
# Epoch 206, Train Loss: 0.7795, Val Loss: 290.7853
# Epoch 207, Train Loss: 0.8228, Val Loss: 302.0445
# Epoch 208, Train Loss: 0.6998, Val Loss: 300.0521
# Epoch 209, Train Loss: 0.7054, Val Loss: 299.9831
# Epoch 210, Train Loss: 0.7511, Val Loss: 293.5946
# Epoch 211, Train Loss: 0.9777, Val Loss: 294.1508
# Epoch 212, Train Loss: 2.3940, Val Loss: 285.2975
# Epoch 213, Train Loss: 0.7302, Val Loss: 285.3157
# Epoch 214, Train Loss: 0.6520, Val Loss: 275.7049
# Epoch 215, Train Loss: 0.7905, Val Loss: 292.8433
# Epoch 216, Train Loss: 1.2358, Val Loss: 284.2955
# Epoch 217, Train Loss: 0.5525, Val Loss: 298.1302
# Epoch 218, Train Loss: 0.5149, Val Loss: 291.8978
# Epoch 219, Train Loss: 0.5931, Val Loss: 311.1536
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[28], line 10
#       8 for xb, yb in train_loader:
#       9     xb, yb = xb.to(device), yb.to(device)
# ---> 10     pred = model(xb)
#      11     loss = criterion(pred, yb)
#      13     optimizer.zero_grad()
#
# File c:\Users\AKSHAT SHAW\anaconda3\Lib\site-packages\torch\nn\modules\module.py:1736, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1734     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1735 else:
# -> 1736     return self._call_impl(*args, **kwargs)
#
# File c:\Users\AKSHAT SHAW\anaconda3\Lib\site-packages\torch\nn\modules\module.py:1747, in Module._call_impl(self, *args, **kwargs)
#    1742 # If we don't have any hooks, we want to skip the rest of the logic in
#    1743 # this function, and just call forward.
#    1744 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1745         or _global_backward_pre_hooks or _global_backward_hooks
#    1746         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1747     return forward_call(*args, **kwargs)
#    1749 result = None
#    1750 called_always_called_hooks = set()
#
# Cell In[24], line 22, in LSTMModel.forward(self, x)
#      20 out, _ = self.lstm2(out)
#      21 out = out[:, -1, :]    # take last time step
# ---> 22 return self.fc(out)
#
# File c:\Users\AKSHAT SHAW\anaconda3\Lib\site-packages\torch\nn\modules\module.py:1918, in Module.__getattr__(self, name)
#    1909         self._backward_pre_hooks = OrderedDict()
#    1911 # On the return type:
#    1912 # We choose to return `Any` in the `__getattr__` type signature instead of a more strict `Union[Tensor, Module]`.
#    1913 # This is done for better interop with various type checkers for the end users.
#    (...)
#    1916 # See full discussion on the problems with returning `Union` here
#    1917 # https://github.com/microsoft/pyright/issues/4213
# -> 1918 def __getattr__(self, name: str) -> Any:
#    1919     if "_parameters" in self.__dict__:
#    1920         _parameters = self.__dict__["_parameters"]
#
# KeyboardInterrupt:
